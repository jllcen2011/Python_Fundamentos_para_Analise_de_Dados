# %% [markdown]
# # Mini-Projeto 2 - Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# c:\Users\jllce\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\jllce\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\jllce\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# c:\Users\jllce\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("C:/Users/jllce/Documents/JLLC/Estudos/Postagens Github/Resoluções do Curso Python_Fundamentos_para_Analise_de_Dados 3.0 (DSAcademy)/03 - MiniProjetoCap09/autos.csv")
df
# Out:
#                 dateCrawled                                   name  seller  \
# 0       2016-03-24 11:52:17                             Golf_3_1.6  privat
# 1       2016-03-23 10:58:45                   A5_Sportback_2.7_Tdi  privat
# 2       2016-03-14 12:52:21         Jeep_Grand_Cherokee_"Overland"  privat
# 3       2016-03-17 16:54:04                     GOLF_4_1_4__3TÜRER  privat
# 4       2016-03-31 17:25:20         Skoda_Fabia_1.4_TDI_PD_Classic  privat
# ...                     ...                                    ...     ...
# 313682  2016-03-21 09:50:58                        Mitsubishi_Cold  privat
# 313683  2016-03-14 17:48:27             Suche_t4___vito_ab_6_sitze  privat
# 313684  2016-03-05 19:56:21  Smart_smart_leistungssteigerung_100ps  privat
# 313685  2016-03-19 18:57:12     Volkswagen_Multivan_T4_TDI_7DC_UY2  privat
# 313686  2016-03-20 19:41:08                 VW_Golf_Kombi_1_9l_TDI  privat
#
# ...

# %% [markdown]
# #### Distribuição de Veículos com base no Ano de Registro
# ###### Crie um Plot com a Distribuição de Veículos com base no Ano de Registro

# %%
sns.displot(df, x=df["yearOfRegistration"], kind="kde", fill=True, height=7)
plt.grid(True)

df["yearOfRegistration"].value_counts().head()
# Out:
# 2000    24313
# 1999    22704
# 2005    21206
# 2001    20063
# 2003    19639
# Name: yearOfRegistration, dtype: int64

# %% [markdown]
# #### Variação da faixa de preço pelo tipo de veículo
#
# ###### Crie um Boxplot para avaliar os outliers

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x=df["vehicleType"], y=df["price"], dodge=False, orient="v")
# Out:
# <AxesSubplot: xlabel='vehicleType', ylabel='price'>

# %% [markdown]
# #### Contagem total de veículos à venda conforme o tipo de veículo
# ###### Crie um Count Plot que mostre o número de veículos pertencentes a cada categoria

# %%
plt.figure(figsize=(12,6))
ax = sns.countplot(x=df["vehicleType"], order=df["vehicleType"].value_counts(ascending=False).index);
abs_values = df["vehicleType"].value_counts(ascending=False).values
rel_values = df["vehicleType"].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]
ax.bar_label(container=ax.containers[0], labels=lbls)
plt.xlabel("Tipo de Veículo")
plt.ylabel("Total de Veículos à Venda")
plt.title("Contagem total de veículos à venda conforme o tipo do veículo")
# Out:
# Text(0.5, 1.0, 'Contagem total de veículos à venda conforme o tipo do veículo')

# %% [markdown]
# ## Análise 2

# %% [markdown]
# #### Número de veículos pertencentes a cada marca
# ###### Crie um Plot que mostre o número de veículos pertencentes a cada marca

# %%
plt.figure(figsize=(12,8))
ay = sns.countplot(y=df["brand"], order=df["brand"].value_counts(ascending=False).index);
abs_values = df["brand"].value_counts(ascending=False).values
rel_values = df["brand"].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]
ay.bar_label(container=ay.containers[0], labels=lbls)
plt.ylabel("Marca de Veículo")
plt.xlabel("Total de Veículos à Venda")
plt.title("Contagem total de veículos à venda conforme a marca do veículo")
# Out:
# Text(0.5, 1.0, 'Contagem total de veículos à venda conforme a marca do veículo')

# %% [markdown]
# #### Preço médio dos veículos com base no tipo de veículo, bem como no tipo de caixa de câmbio
# ###### Crie um Plot com o Preço médio dos veículos com base no tipo de veículo, bem como no tipo de caixa de câmbio

# %%
df2 = df.groupby(['vehicleType', 'gearbox'])["price"].mean()
df2 = df2.reset_index()
df2.rename(columns = {'price':'Average Price'}, inplace = True)
df2
# Out:
#    vehicleType      gearbox  Average Price
# 0        Other  Unspecified     637.746376
# 1        Other    automatik    1216.928197
# 2        Other      manuell     966.845311
# 3       andere  Unspecified    1234.450893
# 4       andere    automatik    2901.823293
# 5       andere      manuell    2456.987680
# 6          bus  Unspecified    3483.163660
# 7          bus    automatik    5719.686344
# 8          bus      manuell    4547.567803
# 9       cabrio  Unspecified    4758.811679
# 10      cabrio    automatik    9014.381548
# 11      cabrio      manuell    6448.555657
# 12       coupe  Unspecified    4861.688699
# 13       coupe    automatik    9546.569811
# 14       coupe      manuell    5642.117982
# 15  kleinwagen  Unspecified    1510.675239
# 16  kleinwagen    automatik    2081.985513
# 17  kleinwagen      manuell    1713.291610
# 18       kombi  Unspecified    2549.287303
# 19       kombi    automatik    5211.097242
# 20       kombi      manuell    3627.133530
# ...

# %%
plt.figure(figsize=(12,8))
ay = sns.barplot(data=df2, y="vehicleType", x="Average Price", hue="gearbox", orient="h")
plt.title("Preço médio dos veículos com base no tipo de veículo e caixa de câmbio")

for i in ay.containers:
    ay.bar_label(i,)

# %% [markdown]
# ## Análise 3

# %% [markdown]
# #### Preço médio do veículo por tipo de combustível e tipo de caixa de câmbio
# ###### Crie um Barplot com o Preço médio do veículo por tipo de combustível e tipo de caixa de câmbio

# %%
df3 = df.groupby(["fuelType", "gearbox"])["price"].mean()
df3 = df3.reset_index()
df3.rename(columns = {'price':'Average Price'}, inplace = True)
df3
# Out:
#     fuelType      gearbox  Average Price
# 0        Cng  Unspecified    2646.307692
# 1        Cng    automatik    5110.156250
# 2        Cng      manuell    4112.617711
# 3     Diesel  Unspecified    3231.736023
# 4     Diesel    automatik    7998.659897
# 5     Diesel      manuell    5221.182161
# 6   Electric  Unspecified    2507.500000
# 7   Electric    automatik    5862.105263
# 8   Electric      manuell    2136.363636
# 9   Gasoline  Unspecified    1909.750207
# 10  Gasoline    automatik    5171.383895
# 11  Gasoline      manuell    3012.665925
# 12    Hybrid  Unspecified    1332.250000
# 13    Hybrid    automatik    8904.259615
# 14    Hybrid      manuell    5166.871795
# 15       Lpg  Unspecified    2615.610169
# 16       Lpg    automatik    5539.479830
# 17       Lpg      manuell    3122.458607
# 18     Other  Unspecified    1108.366890
# 19     Other    automatik    3370.234189
# 20     Other      manuell    1732.633224

# %%
plt.figure(figsize=(12,8))
ay = sns.barplot(data=df3, y="fuelType", x="Average Price", hue="gearbox", orient="h")
plt.title("Preço médio dos veículos com base no tipo de combustível e caixa de câmbio")

for i in ay.containers:
    ay.bar_label(i,)

# %% [markdown]
# #### Potência média de um veículo por tipo de veículo e tipo de caixa de câmbio
# ###### Crie um Barplot com a Potência média de um veículo por tipo de veículo e tipo de caixa de câmbio

# %%
df4 = df.groupby(["vehicleType", "gearbox"])["powerPS"].mean()
df4 = df4.reset_index()
df4.rename(columns = {'powerPS':'Average Power'}, inplace = True)
df4
# Out:
#    vehicleType      gearbox  Average Power
# 0        Other  Unspecified      16.428552
# 1        Other    automatik      81.773373
# 2        Other      manuell      70.732309
# 3       andere  Unspecified      83.214286
# 4       andere    automatik      86.971888
# 5       andere      manuell      92.699795
# 6          bus  Unspecified      45.615979
# 7          bus    automatik     132.590316
# 8          bus      manuell     108.240025
# 9       cabrio  Unspecified      61.727007
# 10      cabrio    automatik     160.628651
# 11      cabrio      manuell     127.318214
# 12       coupe  Unspecified      76.102345
# 13       coupe    automatik     195.687191
# 14       coupe      manuell     144.429150
# 15  kleinwagen  Unspecified      36.925486
# 16  kleinwagen    automatik      67.513659
# 17  kleinwagen      manuell      65.475833
# 18       kombi  Unspecified      50.450556
# 19       kombi    automatik     165.530970
# 20       kombi      manuell     122.375745
# ...

# %%
plt.figure(figsize=(12,8))
ay = sns.barplot(data=df4, y="vehicleType", x="Average Power", hue="gearbox", orient="h")
plt.title("Potência média dos veículos com base no tipo de veículo e caixa de câmbio")

for i in ay.containers:
    ay.bar_label(i,)

# %% [markdown]
# ## Análise 4

# %% [markdown]
# ###### Calcule a média de preço por marca e por veículo

# %%
df5 = df.groupby(["brand","vehicleType"])["price"].mean()
df5 = df5.reset_index()
df5.rename(columns = {'price':'Average Price'}, inplace = True)
df5
# Out:
#           brand vehicleType  Average Price
# 0    alfa_romeo       Other     669.805556
# 1    alfa_romeo      andere     962.500000
# 2    alfa_romeo      cabrio    7035.727778
# 3    alfa_romeo       coupe    5265.458874
# 4    alfa_romeo  kleinwagen    1867.865248
# ..          ...         ...            ...
# 328       volvo       coupe    5502.100000
# 329       volvo  kleinwagen    1475.000000
# 330       volvo       kombi    2789.709828
# 331       volvo   limousine    3768.010084
# 332       volvo         suv   14081.237918
#
# [333 rows x 3 columns]

# %% [markdown]
# #### Preço médio de um veículo por marca, bem como tipo de veículo
# ###### Crie um Heatmap com Preço médio de um veículo por marca, bem como tipo de veículo

# %%
df6 = df5.pivot("brand", "vehicleType", "Average Price")
df6 = df6.fillna(0).astype(int)
df6
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_16148/2700607429.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df6 = df5.pivot("brand", "vehicleType", "Average Price")
# vehicleType     Other  andere   bus  cabrio  coupe  kleinwagen  kombi  \
# brand
# alfa_romeo        669     962     0    7035   5265        1867   3312
# audi             1012    2685  3485    9655  11242        2582   5442
# bmw               896    1720  4064    8613   6375        1575   5030
# chevrolet        1250    3059  5188   10590   9991        2588   4143
# chrysler          915    2919  2395    4160   8194        1666   3930
# citroen           912    2248  4036    4536   2695        2274   3101
# dacia            1674    3560  8370       0      0        3276   4166
# daewoo            664     993  1262     900    428        1110    816
# daihatsu          614    1075  1201    7761      0        1402   3420
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df6.astype(int), annot=True, linewidth=.5, fmt=".0f", cmap="viridis")
plt.xlabel("Marca do Veículo")
plt.ylabel("Tipo de Veículo")
plt.title("Preço médio por marca e tipo de veículo")
# Out:
# Text(0.5, 1.0, 'Preço médio por marca e tipo de veículo')
